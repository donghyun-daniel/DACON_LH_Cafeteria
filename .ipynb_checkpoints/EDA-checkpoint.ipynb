# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

np.random.seed(2)

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import os
import logging

from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.4.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Thu_Jun_11_22:26:48_Pacific_Daylight_Time_2020
# Cuda compilation tools, release 11.0, V11.0.194
# Build cuda_11.0_bu.relgpu_drvr445TC445_37.28540450_0

# %%
weather = pd.read_csv("data/진주기상정보.csv", encoding = "cp949")
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
weather.rename(columns = {"일시" : "일자"}, inplace = True)
train.describe()
# Out:
#              본사정원수       본사휴가자수       본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# count  1205.000000  1205.000000  1205.000000     1205.000000  1205.000000
# mean   2807.815768   157.913693   241.142739      274.117012    43.506224
# std     171.264404   144.190572    43.532298      246.239651   109.937400
# min    2601.000000    23.000000    41.000000        0.000000     0.000000
# 25%    2645.000000    71.000000   217.000000        4.000000     0.000000
# 50%    2760.000000   105.000000   245.000000      299.000000     0.000000
# 75%    2962.000000   185.000000   272.000000      452.000000     0.000000
# max    3305.000000  1224.000000   378.000000     1044.000000   533.000000
#
#                중식계          석식계
# count  1205.000000  1205.000000
# mean    890.334440   461.772614
# std     209.505057   139.179202
# min     296.000000     0.000000
# 25%     758.000000   406.000000
# 50%     879.000000   483.000000
# 75%    1032.000000   545.000000
# max    1459.000000   905.000000

# %%
# train_merge = pd.merge(train, weather, on = "일자", how = "left")
# test_merge = pd.merge(test, weather, on = "일자", how = "left")
# train_merge.describe()

# %%
train_merge = train
test_merge = test

# %%
# !pip install lxml
import requests
from urllib import parse
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

def getHoliday(year: int) -> pd.DataFrame:
    url = "http://apis.data.go.kr/B090041/openapi/service/SpcdeInfoService/getRestDeInfo"
    api_key_utf8 = "I2Mv6nH4CWf3VYYi83oy0EJO2upQgmp2GDI%2Fdbxh9ekXkRD4EjMSq0gWZxTy%2FNtAxnjV7soTkOW2xs1qYMdjBg%3D%3D"
    api_key_decode = parse.unquote(api_key_utf8)

    params = {
        "ServiceKey": api_key_decode,
        "solYear": year,
        "numOfRows": 100
    }

    response = requests.get(url, params=params)
    xml = BeautifulSoup(response.text, "html.parser")
    items = xml.find('items')
    item_list = []
    for item in items:
        item_dict = {
            "공휴일": 1, # 무슨 공휴일인지는 없어도 될 듯 하다
            "일자": datetime.strptime(item.find("locdate").text.strip(), '%Y%m%d')
        }
        item_list.append(item_dict)

    return pd.DataFrame(item_list)
# Out:
# Requirement already satisfied: lxml in c:\users\dongh\anaconda3\envs\python3.8\lib\site-packages (4.6.3)

# %%
holidays = pd.concat([getHoliday(year) for year in range(2016, 2022)])
holidays.describe()
# Out:
#          공휴일
# count  103.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0

# %%
from datetime import datetime, timedelta

def one_day_before(s):
    return str(datetime.strptime(str(s)[:10], "%Y-%m-%d").date() + timedelta(days = -1))

def one_day_after(s):
    return str(datetime.strptime(str(s)[:10], "%Y-%m-%d").date() + timedelta(days = 1))

holidays["공휴일전날"] = holidays["일자"].apply(one_day_before)
holidays["공휴일다음날"] = holidays["일자"].apply(one_day_after)

# %%
new_holidays = pd.concat([holidays["공휴일전날"], holidays["공휴일다음날"]])

new_holidays = pd.DataFrame(new_holidays, columns = ["일자"])

new_holidays["휴일전후날여부"] = 1
new_holidays.head(110)
# Out:
#             일자  휴일전후날여부
# 0   2015-12-31        1
# 1   2016-02-06        1
# 2   2016-02-07        1
# 3   2016-02-08        1
# 4   2016-02-09        1
# ..         ...      ...
# 2   2016-02-09        1
# 3   2016-02-10        1
# 4   2016-02-11        1
# 5   2016-03-02        1
# 6   2016-04-14        1
#
# [110 rows x 2 columns]

# %%
train_merge = pd.merge(train_merge, new_holidays, how = 'left', on  = '일자')
test_merge = pd.merge(test_merge, new_holidays, how = 'left', on = '일자')

train_merge["휴일전후날여부"] = train_merge["휴일전후날여부"].fillna(0)
test_merge["휴일전후날여부"] = test_merge["휴일전후날여부"].fillna(0)

# keep submission source
submission = test_merge[["일자"]]

train_merge.drop(["일자"], inplace = True, axis = 1)
test_merge.drop(["일자"], inplace = True, axis = 1)
train_merge.head(50)
# Out:
#    요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0   월   2601      50     150             238          0.0
# 1   화   2601      50     173             319          0.0
# 2   수   2601      56     180             111          0.0
# 3   목   2601     104     220             355          0.0
# 4   금   2601     278     181              34          0.0
# 5   목   2601     383     143             417          0.0
# 6   금   2601     389     156              93          0.0
# 7   월   2601      87     204             482          0.0
# 8   화   2601      72     236             526          0.0
# 9   수   2601      78     250              23          0.0
# 10  목   2601      77     254             367          0.0
# 11  금   2601     145     252              69          0.0
# 12  월   2601      90     207             434          0.0
# 13  화   2601      57     237             488          0.0
# 14  수   2601      54     232              14          0.0
# 15  목   2601      56     261             335          0.0
# 16  금   2601     144     278              42          0.0
# 17  월   2601     595     168             110          0.0
# 18  수   2624     127     182             261          0.0
# 19  목   2624      61     224             351          0.0
# 20  금   2624      83     247              79          0.0
# 21  월   2624      50     195             456          0.0
# 22  화   2624      47     212             426          0.0
# 23  수   2624      43     225               0          0.0
# 24  목   2624      55     245             290          0.0
# 25  금   2624     108     275              76          0.0
# 26  월   2624      61     183             376          0.0
# 27  화   2624      38     231             399          0.0
# 28  수   2624      50     213               0          0.0
# 29  목   2624      52     242             327          0.0
# 30  금   2624     118     277              57          0.0
# 31  월   2624      65     205             329          0.0
# 32  화   2624      41     208             378          0.0
# 33  수   2624      42     236               0          0.0
# 34  목   2624      53     251             293          0.0
# 35  금   2624      98     275              59          0.0
# 36  월   2624      77     197             299          0.0
# 37  화   2624      52     245             259          0.0
# 38  수   2624      48     230               0          0.0
# 39  목   2624      36     248             158          0.0
# 40  금   2643     103     254              47          0.0
# 41  월   2643      62     221             367          0.0
# 42  화   2643      31     242             370          0.0
# 43  수   2643      37     249               0          0.0
# 44  목   2643      47     258             339          0.0
# 45  금   2643      87     283              64          0.0
# 46  월   2643      82     203             392          0.0
# 47  화   2643      76     225             239          0.0
# 48  목   2643     106     252             326          0.0
# 49  금   2643     131     281              82          0.0
#
#                                                  조식메뉴  \
# 0   모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1   모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
# 2   모닝롤/베이글  우유/두유/주스 계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 콩나물국...
# 3   모닝롤/토마토샌드  우유/두유/주스 계란후라이  닭죽/쌀밥 (쌀,닭:국내산) 근대국...
# 4   모닝롤/와플  우유/두유/주스 계란후라이  쇠고기죽/쌀밥 (쌀:국내산) 재첩국  방...
# 5   팬케익/찐빵  우유/두유/주스  계란후라이  견과류죽/쌀밥 (쌀:국내산) 감자찌개 ...
# 6   모닝롤/야채샌드  우유/두유/주스  계란후라이  고구마죽/쌀밥 (쌀:국내산) 봄동된...
# 7   모닝롤/치즈프레즐  우유/두유/주스  계란후라이  잣죽/쌀밥 (쌀:국내산) 민물새우...
# 8   모닝롤/마늘빵  우유/두유/주스  계란후라이  단호박죽/쌀밥 (쌀:국내산) 어묵국 ...
# 9   모닝롤/참치샌드  우유/두유/주스  계란후라이  흑임자죽/쌀밥 (쌀:국내산) 북어계...
# 10  모닝롤/인절미토스트  우유/두유/주스  계란후라이  계란후라이  (쌀:국내산) 선지...
# 11  모닝롤/씨크립샌드  우유/두유/주스  계란후라이  밤죽/쌀밥 (쌀:국내산) 홍합탕 ...
# 12  모닝롤/팬케익  우유/주스  계란후라이  브로컬리죽/쌀밥 (쌀:국내산) 고추장찌개 ...
# 13  모닝롤/야채샌드  우유/주스  계란후라이  닭죽/쌀밥 (쌀:국내산) 재첩국  참나물...
# 14  모닝롤/꿀호떡  우유/주스  계란후라이  김치죽/쌀밥 (쌀:국내산) 무채국  애호박...
# 15  모닝롤/크로와상  우유/주스  계란후라이  쇠고기죽/쌀밥 (쌀:국내산) 봄동된장국 ...
# 16  모닝롤/에그샌드  우유/주스  계란후라이  밤죽/쌀밥 (쌀:국내산) 꽃게탕  시래기...
# 17  모닝롤/프렌치토스트  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 콩나물...
# 18  모닝롤/단팥빵  우유/두유/주스 계란후라이  참치야채죽/쌀밥 (쌀:국내산) 올갱이아...
# 19  모닝롤/바나나샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 피바지락국...
# 20  모닝롤/사과파이  우유/두유/주스 계란후라이  야채죽/쌀밥 (쌀:국내산) 시금치국 ...
# 21  모닝롤/브라우니  우유/두유/주스  계란후라이  땅콩죽/쌀밥 (쌀:국내산) 무채국 ...
# 22  모닝롤/고구마샌드  우유/두유/주스  계란후라이  새송이죽/쌀밥 (쌀:국내산) 호박...
# 23  모닝롤/롤케익  우유/두유/주스  계란후라이  단호박죽/쌀밥 (쌀:국내산) 어묵국 ...
# 24  모닝롤/햄치즈샌드  우유/두유/주스  계란후라이  녹두죽/쌀밥 (쌀:국내산) 냉이된...
# 25  모닝롤/찐빵  우유/두유/주스  계란후라이  고구마죽/쌀밥 (쌀:국내산) 재첩국  ...
# 26  모닝롤/롤케이크  우유/주스  계란후라이  흑임자죽/쌀밥 (쌀:국내산) 황태국  미...
# 27  모닝롤/에그샌드  우유/주스  계란후라이  해물죽/쌀밥 (쌀:국내산) 쇠고기무국  ...
# 28  모닝롤/치즈프레즐  우유/주스  계란후라이  홍게살죽/쌀밥 (쌀:국내산) 시래기국 ...
# 29  모닝롤/베이컨샌드  우유/주스  계란후라이  브로컬리죽/쌀밥 (쌀:국내산) 오징어국...
# 30  모닝롤/크로와상  우유/주스  계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 들깨미역국...
# 31  모닝롤/마늘빵  우유/주스  계란후라이  김치죽/쌀밥 (쌀:국내산) 무채국  김실파...
# 32  모닝롤/씨크립샌드  우유/주스  계란후라이  참치야채죽/쌀밥 (쌀:국내산) 선지해장...
# 33  모닝롤/카스텔라  우유/주스  계란후라이  새송이버섯죽/쌀밥 (쌀:국내산) 근대국 ...
# 34  모닝롤/토마토샌드  우유/주스  계란후라이  밤죽/쌀밥 (쌀:국내산) 순두부국  크...
# 35  모닝롤/와플  우유/주스  계란후라이  견과류죽/쌀밥 (쌀:국내산) 콩나물국  진미...
# 36  모닝롤/프렌치토스트  우유/주스  계란후라이  새우살죽/쌀밥 (쌀:국내산) 두부김치...
# 37  모닝롤/참치샌드  우유/주스  계란후라이  야채죽/쌀밥 (쌀:국내산) 쇠고기버섯국 ...
# 38  모닝롤/핫도그  우유/주스  계란후라이  닭죽/쌀밥 (쌀:국내산) 감자국  참나물무...
# 39  모닝롤/단팥빵  우유/주스  계란후라이  늙은호박죽/쌀밥 (쌀:국내산) 바지락쑥국 ...
# 40  모닝롤/야채샌드  우유/주스  계란후라이  녹두죽/쌀밥 (쌀:국내산) 민물새우찌개 ...
# 41  모닝롤/팬케익  우유/두유/주스 계란후라이  잣죽/쌀밥 (쌀:국내산) 근대국  마늘...
# 42  모닝롤/단호박샌드  우유/두유/주스 계란후라이  양송이죽/쌀밥 (쌀:국내산) 두부젓...
# 43  모닝롤/치즈프레즐  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 꽃게탕  ...
# 44  모닝롤/치킨샌드  우유/두유/주스 계란후라이  흑임자죽/쌀밥 (쌀:국내산) 열무된장...
# 45  모닝롤/브라우니  우유/두유/주스 계란후라이  고구마죽/쌀밥 (쌀:국내산) 대구찌개...
# 46  모닝롤/마늘빵  우유/두유/주스 계란후라이  견과류죽/쌀밥 (쌀:국내산) 고추장찌개...
# 47  모닝롤/씨크립샌드  우유/두유/주스 계란후라이  쇠고기죽/쌀밥 (쇠고기:호주산,쌀:...
# 48  모닝롤/에그샌드  우유/두유/주스 계란후라이  브로컬리죽/쌀밥 (쌀:국내산) 황태국...
# 49  모닝롤/크로와상  우유/두유/주스 계란후라이  새우살죽/쌀밥 (쌀:국내산) 재첩국 ...
#
#                                                  중식메뉴  \
# 0   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
# 2   카레덮밥 (쌀,현미흑미:국내산) 팽이장국  치킨핑거 (닭고기:국내산) 쫄면야채무침 ...
# 3   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 쇠고기무국  주꾸미볶음  부추전  시금치나물  ...
# 4   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 떡국  돈육씨앗강정 (돼지고기:국내산) 우엉잡채...
# 5   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 시래기국  훈제오리구이  도토리묵무침  쌈무/양...
# 6   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 꽃게탕  돈육굴소스볶음  옥수수전  유채나물  ...
# 7   쌀밥/잡곡밥 (쌀:국내산) 시금치국  닭감자조림 (닭고기:국내산) 연두부*양념장  ...
# 8   쌀밥/잡곡밥 (쌀:국내산) 쇠고기무국 (쇠고기:호주산) 탕수어 (동태:러시아산) 오...
# 9   쌀밥/잡곡밥 (쌀:국내산) 냉이된장국  쇠고기장조림 (쇠고기:호주산) 통도라지구이 ...
# 10  낙지비빔밥 (낙지:중국산,쌀:국내산) 유부장국  고구마치즈구이  해초무침  요구르트...
# 11  쌀밥/잡곡밥 (쌀:국내산) 대구찌개  마늘간장치킨 (닭고기:국내산) 새송이버섯볶음 ...
# 12  쌀밥/오곡밥 (쌀:국내산) 쇠고기느타리국  갈치구이  호박꼬지&고사리&무나물  파래...
# 13  쌀밥/잡곡밥 (쌀:국내산) 콩나물국  돈육간장볶음  버섯잡채  꽃상추무침  요구르트...
# 14  비빔밥 (쌀:국내산) 팽이장국  소세지피망볶음  맛탕  귤  요구르트  포기김치 (...
# 15  쌀밥/잡곡밥 (쌀:국내산) 북어계란국  닭갈비  새싹두부구이  곰피초장  요구르트 ...
# 16  쌀밥/잡곡밥 (쌀:국내산) 수제비국  오징어볶음  계란찜  도라지초무침  요구르트 ...
# 17  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 얼갈이된장국  제육볶음  늙은호박전  치커리생채...
# 18  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 쇠고기미역국  주꾸미볶음  맛살계란말이  아삭고...
# 19  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 근대된장국  탕수육  새송이버섯조림  무생채  ...
# 20  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 부대찌개  가자미튀김  메추리알조림  열무된장나...
# 21  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 콩나물국  닭갈비 (닭고기:국내산) 모둠묵*양념...
# 22  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 차돌박이찌개 (쇠고기:호주산) 고등어김치말이  ...
# 23  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 북어국  돈육장조림 (돼지고기:국내산) 홍어무침...
# 24  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 고추장찌개  닭데리야끼조림  해물파전  취나물 ...
# 25  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 배추된장국  수제돈가스 (돼지고기:국내산) 탕평...
# 26  쌀밥/잡곡밥 (쌀:국내산) 어묵국  돈육고추장볶음 (돼지고기:국내산) 모둠양채쌈*쌈...
# 27  쌀밥/잡곡밥 (쌀:국내산) 쑥국  소불고기 (쇠고기:호주산) 골뱅이무침*소면  마늘...
# 28  곤드레밥 (쌀:국내산) 콩나물김치국  미니채소떡갈비 (쇠고기:호주산.돈육:국내산) ...
# 29  쌀밥/잡곡밥 (쌀:국내산) 사골우거지국 (쇠고기:호주산) 탕수어  파래김*양념장  ...
# 30  쌀밥/잡곡밥 (쌀:국내산) 시금치국  훈제오리구이  연근땅콩조림  쌈무/부추생채  ...
# 31   쌀밥/잡곡밥 (쌀:국내산) 꽃게탕  버섯불고기 (쇠고기:호주산) 계란말이  도토리...
# 32   쌀밥/잡곡밥 (쌀:국내산) 쇠고기샤브국 (쇠고기:호주산) 코다리강정  두부&김치볶...
# 33   콩나물밥*달래장 (쌀:국내산) 맑은국  치킨텐더*요거트D (닭고기:국내산) 땅콩조...
# 34   쌀밥/잡곡밥 (쌀:국내산) 북어계란국  쇠고기장조림 (쇠고기:호주산) 오징어초무침...
# 35   쌀밥/잡곡밥 (쌀:국내산) 닭개장 (닭고기:국내산) 자반고등어구이 (고등어:국내산...
# 36   쌀밥/잡곡밥 (쌀:국내산) 얼갈이된장국  닭갈비  해파리냉채  취나물  포기김치 ...
# 37   쌀밥/잡곡밥 (쌀:국내산) 옹심이만두국  주꾸미볶음  새송이버섯전  치커리유자청생...
# 38   봄새싹비빔밥 (쌀:국내산) 쪽파국  오징어튀김  알감자버터구이  오렌지  포기김치...
# 39   쌀밥/잡곡밥 (쌀:국내산) 매운콩나물국  돈육굴소스볶음  동태전  봄동나물  포기...
# 40   쌀밥/잡곡밥 (쌀:국내산) 버섯들깨탕  갈치조림  우엉잡채  아삭고추무침  포기김...
# 41  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 순두부찌개  쇠불고기  브로컬리맛살볶음  풋마늘...
# 42  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 북어국  오징어볶음*소면  모둠소시지구이  시금...
# 43  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 올갱이아욱국  제육볶음  두부조림  모둠쌈*쌈장...
# 44  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 어묵국  매운돼지갈비찜  해물파전  무생채  포...
# 45  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 배추된장국  순살양념치킨  메추리알조림  콩나물...
# 46  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 시래기국  훈제오리구이 (훈제오리:국내산) 무쌈...
# 47  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 부대찌개  쇠고기단호박조림 (쇠고기:호주산) 열...
# 48  쌀밥/잡곡밥 (쌀,현미흑미:국내산)  수제비국  돈육굴소스볶음 (돼지고기:국내산) ...
# 49  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 냉이된장찌개  닭데리야끼조림 (닭고기:국내산) ...
#
#                                                  석식메뉴     중식계    석식계  휴일전후날여부
# 0   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0      0.0
# 1   콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0      0.0
# 2   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 청국장찌개  황태양념구이 (황태:러시아산) 고기...  1017.0  573.0      0.0
# 3   미니김밥*겨자장 (쌀,현미흑미:국내산) 우동  멕시칸샐러드  군고구마  무피클  포...   978.0  525.0      0.0
# 4   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 차돌박이찌개 (쇠고기:호주산) 닭갈비 (닭고기:...   925.0  330.0      0.0
# 5   참치회덮밥 (쌀,현미흑미:국내산) 맑은국  군만두  과일샐러드  락교  포기김치 (...  1045.0  550.0      1.0
# 6   쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치콩나물국  미니함박  어묵볶음  물파래무침 ...   909.0  598.0      0.0
# 7   쌀밥/잡곡밥 (쌀:국내산) 홍합미역국  등갈비김치찜 (돼지고기,김치:국내산) 임연수...  1268.0  672.0      0.0
# 8   쌀밥/잡곡밥 (쌀:국내산) 된장찌개  쇠불고기 (쇠고기:호주산) 해파리겨자채  봄동...  1014.0  523.0      0.0
# 9   볶음밥*자장소스 (쌀:국내산) 맑은국  새우또띠아  쨔샤이무침  요플레  포기김치 ...   916.0  588.0      0.0
# 10  쌀밥/잡곡밥 (쌀:국내산) 순두부찌개  명태조림 (명태:러시아산) 감자채볶음  쌈만...   910.0  489.0      0.0
# 11  쌀밥/잡곡밥 (쌀:국내산) 설렁탕 (쇠고기:호주산) 김치전 (김치:국내산) 야채스틱...   763.0  597.0      0.0
# 12  쌀밥/잡곡밥 (쌀:국내산) 옹심이만두국  떡갈비조림  청포묵무침  부추오이생채  포...  1298.0  645.0      0.0
# 13  쌀밥/잡곡밥 (쌀:국내산) 콩비지찌개  해물까스&타르타르소스  볶음쌀국수  미역레몬...   899.0  610.0      0.0
# 14  쌀밥/잡곡밥 (쌀:국내산) 열무된장국  매운돼지갈비찜  멸치호두볶음  숙주나물  포...  1022.0  514.0      0.0
# 15  김밥 (쌀:국내산) 잔치국수  교자만두 (오븐에 찜) 멕시칸샐러드  무피클  포기김...   917.0  531.0      0.0
# 16  쌀밥/잡곡밥 (쌀:국내산) 닭개장  삼치구이  꽃맛살볶음  청경채사과무침  포기김치...   766.0  585.0      0.0
# 17  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 버섯들깨탕  꽁치한마리구이  두부양념조림  구이...   869.0  344.0      1.0
# 18  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 된장찌개  버섯불고기  콩나물겨자채  양념깻잎지...  1127.0  631.0      1.0
# 19  멸치주먹밥 (쌀,현미흑미:국내산) 우동  떡볶이  군고구마  단무지  포기김치 (배...  1000.0  473.0      0.0
# 20  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어국  미트볼조림  옥수수전  부추생채  포...   837.0  673.0      0.0
# 21  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 대구찌개 돈육굴소스볶음  감자채볶음  물파래무침...  1326.0  625.0      0.0
# 22  카레덮밥 (쌀,현미흑미:국내산) 가쯔오장국 수제고로케*케찹  과일샐러드  오복지  ...  1026.0  609.0      0.0
# 23  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장 생선까스*탈탈소스  야채계란찜  콩나물무...   901.0  523.0      0.0
# 24  볶음밥 (쌀,현미흑미:국내산) 짬뽕 개성감자만두  타코야끼  꼬들단무지   포기김치...   847.0  525.0      0.0
# 25  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 연두부탕 코다리무조림  고추잡채*꽃빵  봄동겉절...   728.0  591.0      0.0
# 26  쌀밥/잡곡밥 (쌀:국내산) 달래된장찌개  간장찜닭 (닭고기:국내산) 통도라지구이 참...  1286.0  586.0      0.0
# 27  짜장잡채덮밥 (돈육,쌀:국내산) 계란파국  참치야채전  꽃맛살샐러드 오이무침   포...   958.0  545.0      0.0
# 28  쌀밥/잡곡밥 (쌀:국내산) 뼈해장국 (돼지고기:국내산) 해물청경채볶음  버섯메밀전 ...   998.0  531.0      0.0
# 29  토마토스파게티 (쌀:국내산) 양송이스프  미니햄버거 (돼지고기:국내산) 단호박범벅 ...   832.0  548.0      0.0
# 30  쌀밥/잡곡밥 (쌀:국내산) 닭곰탕 (닭고기:국내산) 임연수찜  어묵곤약볶음 돌나물초...   757.0  521.0      0.0
# 31  쌀밥/잡곡밥 (쌀:국내산) 수제비국  아귀콩나물찜  새송이버섯볶음  봄동겉절이  포...  1030.0  605.0      0.0
# 32  굴소스파인볶음밥 (쌀:국내산) 가쯔오장국  찹쌀순대볶음  궁중떡찜  두반장가지나물 ...   917.0  585.0      0.0
# 33  쌀밥/잡곡밥 (쌀:국내산) 알탕  동그랑땡전  마파두부 (돼지고기:국내산) 시금치나...   963.0  544.0      0.0
# 34  참치회덮밥 (쌀:국내산) 미소장국  군만두  콘샐러드  바나나  포기김치 (김치:국...   876.0  507.0      0.0
# 35  쌀밥/잡곡밥 (쌀:국내산) 냉이된장찌개  누룽지탕수육 (돼지고기:국내산) 감자채볶음...   861.0  523.0      0.0
# 36  쌀밥/잡곡밥 (쌀:국내산) 콩비지찌개  유산슬  해물까스*탈탈소스  도라지나물  포...  1193.0  637.0      0.0
# 37  햄볶음밥 (쌀:국내산) 유부장국  돈육씨앗강정  해초무침  깨찰빵  포기김치 (김치...   892.0  465.0      0.0
# 38  쌀밥/잡곡밥 (쌀:국내산) 어묵국  등갈비김치찜  청포묵무침  애호박나물  깍두기 ...  1033.0  463.0      0.0
# 39  주먹밥 (쌀:국내산) 잔치국수  또띠아피자  과일샐러드  오이피클  포기김치 (김치...   781.0  526.0      0.0
# 40  쌀밥/잡곡밥 (쌀:국내산) 쇠고기미역국  순살깐풍기  계란찜  숙주미나리나물  포기...   661.0  591.0      0.0
# 41  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 된장찌개  고등어조림  고기전  부추생채  포기...  1237.0  614.0      0.0
# 42  김치볶음밥 (쌀,현미흑미:국내산) 가쯔오장국  감자치즈구이  꽃맛살샐러드  단무지 ...   840.0  555.0      0.0
# 43  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 매운버섯국  찜닭  탕평채  청경채생채  포기김...   876.0  492.0      0.0
# 44  김밥 (쌀,현미흑미:국내산) 우동  야채튀김  조각사과  오복지  포기김치 (배추,...   853.0  524.0      0.0
# 45  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어국  미니함박  멸치호두볶음  치커리사과무...   764.0  542.0      0.0
# 46  쌀밥/잡곡밥 (쌀:국내산) 쇠고기무국 (쇠고기:호주산) 가자미찜  계란야채말이  돌...  1225.0  536.0      0.0
# 47  치킨마요덮밥 (닭,쌀:국내산) 유부주머니국  떡볶이  단무지무침  오렌지  포기김치...   771.0  500.0      1.0
# 48  비빔밥 (쌀:국내산) 팽이버섯장국  새우또띠아  견과류조림  피크닉  포기김치 (김...   969.0  562.0      1.0
# 49  쌀밥/잡곡밥 (쌀:국내산) 들깨미역국  수제돈가스  감자범벅  참나물생채  포기김치...   579.0  582.0      0.0

# %%
train_merge = pd.get_dummies(train_merge, columns = ["휴일전후날여부"], prefix = '휴일전후날여부')
test_merge = pd.get_dummies(test_merge, columns = ["휴일전후날여부"], prefix = '휴일전후날여부')

# %%
train_merge["본사실근무자수"] = train_merge["본사정원수"] - train_merge["본사휴가자수"] - train_merge["본사출장자수"]/2 - train_merge["현본사소속재택근무자수"]
test_merge["본사실근무자수"] = test_merge["본사정원수"] - test_merge["본사휴가자수"] - test_merge["본사출장자수"]/2 - test_merge["현본사소속재택근무자수"]

del_features = ["본사정원수", "본사휴가자수", "본사출장자수", "현본사소속재택근무자수"]
train_merge.drop(del_features, inplace = True, axis = 1)
test_merge.drop(del_features, inplace = True, axis = 1)

# %%
train_merge = pd.get_dummies(train_merge, columns = ["요일"], prefix = '요일')
test_merge = pd.get_dummies(test_merge, columns = ["요일"], prefix = '요일')
train_merge.head()
# Out:
#    본사시간외근무명령서승인건수                                               조식메뉴  \
# 0             238  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1             319  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
# 2             111  모닝롤/베이글  우유/두유/주스 계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 콩나물국...
# 3             355  모닝롤/토마토샌드  우유/두유/주스 계란후라이  닭죽/쌀밥 (쌀,닭:국내산) 근대국...
# 4              34  모닝롤/와플  우유/두유/주스 계란후라이  쇠고기죽/쌀밥 (쌀:국내산) 재첩국  방...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
# 2  카레덮밥 (쌀,현미흑미:국내산) 팽이장국  치킨핑거 (닭고기:국내산) 쫄면야채무침 ...
# 3  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 쇠고기무국  주꾸미볶음  부추전  시금치나물  ...
# 4  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 떡국  돈육씨앗강정 (돼지고기:국내산) 우엉잡채...
#
#                                                 석식메뉴     중식계    석식계  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0
# 2  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 청국장찌개  황태양념구이 (황태:러시아산) 고기...  1017.0  573.0
# 3  미니김밥*겨자장 (쌀,현미흑미:국내산) 우동  멕시칸샐러드  군고구마  무피클  포...   978.0  525.0
# 4  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 차돌박이찌개 (쇠고기:호주산) 닭갈비 (닭고기:...   925.0  330.0
#
#    휴일전후날여부_0.0  휴일전후날여부_1.0  본사실근무자수  요일_금  요일_목  요일_수  요일_월  요일_화
# 0            1            0   2476.0     0     0     0     1     0
# 1            1            0   2464.5     0     0     0     0     1
# 2            1            0   2455.0     0     0     1     0     0
# 3            1            0   2387.0     0     1     0     0     0
# 4            1            0   2232.5     1     0     0     0     0

# %%
import re
def reg_modi(s):
    s = re.sub(pattern = r'\[[\S]*\]', repl = " ", string = s)
    s = re.sub(pattern = r'\([\S]*\)', repl = " ", string = s)
    s = re.sub(pattern = r'\s\s+', repl = " ", string = s)
    s = re.sub(pattern = r'\*', repl = " ", string = s)
    s = re.sub(pattern = r' $', repl = "", string = s)
    if len(s) < 15 or "개발의" in s or "가정의" in s: # issue
        return "메뉴없음"
    return s

for menu in ["조식메뉴", "중식메뉴", "석식메뉴"]:
    train_merge[menu] = train_merge[menu].apply(reg_modi)
    test_merge[menu] = test_merge[menu].apply(reg_modi)
train_merge.head()
# Out:
#    본사시간외근무명령서승인건수                                               조식메뉴  \
# 0             238       모닝롤/찐빵 우유/두유/주스 계란후라이 호두죽/쌀밥 된장찌개 쥐어채무침 포기김치
# 1             319   모닝롤/단호박샌드 우유/두유/주스 계란후라이 팥죽/쌀밥 호박젓국찌개 시래기조림 포기김치
# 2             111  모닝롤/베이글 우유/두유/주스 계란후라이 표고버섯죽/쌀밥 콩나물국 느타리호박볶음 포기김치
# 3             355       모닝롤/토마토샌드 우유/두유/주스 계란후라이 닭죽/쌀밥 근대국 멸치볶음 포기김치
# 4              34        모닝롤/와플 우유/두유/주스 계란후라이 쇠고기죽/쌀밥 재첩국 방풍나물 포기김치
#
#                                          중식메뉴  \
# 0       쌀밥/잡곡밥 오징어찌개 쇠불고기 계란찜 청포묵무침 요구르트 포기김치
# 1  쌀밥/잡곡밥 김치찌개 가자미튀김 모둠소세지구이 마늘쫑무침 요구르트 배추겉절이
# 2       카레덮밥 팽이장국 치킨핑거 쫄면야채무침 견과류조림 요구르트 포기김치
# 3      쌀밥/잡곡밥 쇠고기무국 주꾸미볶음 부추전 시금치나물 요구르트 포기김치
# 4       쌀밥/잡곡밥 떡국 돈육씨앗강정 우엉잡채 청경채무침 요구르트 포기김치
#
#                                    석식메뉴     중식계    석식계  휴일전후날여부_0.0  \
# 0    쌀밥/잡곡밥 육개장 자반고등어구이 두부조림 건파래무침 포기김치  1039.0  331.0            1
# 1      콩나물밥 양념장 어묵국 유산슬 아삭고추무침 바나나 포기김치   867.0  560.0            1
# 2  쌀밥/잡곡밥 청국장찌개 황태양념구이 고기전 새송이버섯볶음 포기김치  1017.0  573.0            1
# 3      미니김밥 겨자장 우동 멕시칸샐러드 군고구마 무피클 포기김치   978.0  525.0            1
# 4  쌀밥/잡곡밥 차돌박이찌개 닭갈비 감자소세지볶음 콩나물무침 포기김치   925.0  330.0            1
#
#    휴일전후날여부_1.0  본사실근무자수  요일_금  요일_목  요일_수  요일_월  요일_화
# 0            0   2476.0     0     0     0     1     0
# 1            0   2464.5     0     0     0     0     1
# 2            0   2455.0     0     0     1     0     0
# 3            0   2387.0     0     1     0     0     0
# 4            0   2232.5     1     0     0     0     0

# %%
# for word2vec

def split_str(s):
    s = s.split(" ")
    return s

menus = ["조식메뉴", "중식메뉴", "석식메뉴"]
foods = []
for menu in menus:
    foods += train_merge[menu].apply(split_str).to_list()
# Out:
# [['모닝롤/찐빵', '우유/두유/주스', '계란후라이', '호두죽/쌀밥', '된장찌개', '쥐어채무침', '포기김치'], ['모닝롤/단호박샌드', '우유/두유/주스', '계란후라이', '팥죽/쌀밥', '호박젓국찌개', '시래기조림', '포기김치'], ['모닝롤/베이글', '우유/두유/주스', '계란후라이', '표고버섯죽/쌀밥', '콩나물국', '느타리호박볶음', '포기김치'], ['모닝롤/토마토샌드', '우유/두유/주스', '계란후라이', '닭죽/쌀밥', '근대국', '멸치볶음', '포기김치'], ['모닝롤/와플', '우유/두유/주스', '계란후라이', '쇠고기죽/쌀밥', '재첩국', '방풍나물', '포기김치'], ['팬케익/찐빵', '우유/두유/주스', '계란후라이', '견과류죽/쌀밥', '감자찌개', '명엽채무침', '포기김치'], ['모닝롤/야채샌드', '우유/두유/주스', '계란후라이', '고구마죽/쌀밥', '봄동된장국', '숙주나물', '포기김치'], ['모닝롤/치즈프레즐', '우유/두유/주스', '계란후라이', '잣죽/쌀밥', '민물새우찌개', '콩조림', '포기김치'], ['모닝롤/마늘빵', '우유/두유/주스', '계란후라이', '단호박죽/쌀밥', '어묵국', '김구이', '포기김치'], ['모닝롤/참치샌드', '우유/두유/주스', '계란후라이', '흑임자죽/쌀밥', '북어계란국', '무생채', '포기김치'], ['모닝롤/인절미토스트', '우유/두유/주스', '계란후라이', '계란후라이', '선지해장국', '톳두부무침', '포기김치'], ['모닝롤/씨크립샌드', '우유/두유/주스', '계란후라이', '밤죽/쌀밥', '홍합탕', '오이생채', '포기김치'], ['모닝롤/팬케익', '우유/주스', '계란후라이', '브로컬리죽/쌀밥', '고추장찌개', '시금치나물', '포기김치'], ['모닝롤/야채샌드', '우유/주스', '계란후라이', '닭죽/쌀밥', '재첩국', '참나물땅콩가루무침', '포기김치'], ['모닝롤/꿀호떡', '우유/주스', '계란후라이', '김치죽/쌀밥', '무채국', '애호박나물', '포기김치'], ['모닝롤/크로와상', '우유/주스', '계란후라이', '쇠고기죽/쌀밥', '봄동된장국', '어묵볶음', '포기김치'], ['모닝롤/에그샌드', '우유/주스', '계란후라이', '밤죽/쌀밥', '꽃게탕', '시래기조림', '포기김치'], ['모닝롤/프렌치토스트', '우유/두유/주스', '계란후라이', '호두죽/쌀밥', '콩나물김치국', '곰피초장', '포기김치'], ['모닝롤/단팥빵', '우유/두유/주스', '계란후라이', '참치야채죽/쌀밥', '올갱이아욱국', '오이무침', '포기김치'], ['모닝롤/바나나샌드', '우유/두유/주스', '계란후라이', '팥죽/쌀밥', '피바지락국', '가지볶음', '포기김치'], ['모닝롤/사과파이', '우유/두유/주스', '계란후라이', '야채죽/쌀밥', '시금치국', '볼어묵볶음', '포기김치'], ['모닝롤/브라우니', '우유/두유/주스', '계란후라이', '땅콩죽/쌀밥', '무채국', '쑥갓무침', '포기김치'], ['모닝롤/고구마샌드', '우유/두유/주스', '계란후라이', '새송이죽/쌀밥', '호박젓국찌개', '유채나물', '포기김치'], ['모닝롤/롤케익', '우유/두유/주스', '계란후라이', '단호박죽/쌀밥', '어묵국', '김자반', '포기김치'], ['모닝롤/햄치즈샌드', '우유/두유/주스', '계란후라이', '녹두죽/쌀밥', '냉이된장국', '명엽채무침', '포기김치'], ['모닝롤/찐빵', '우유/두유/주스', '계란후라이', '고구마죽/쌀밥', '재첩국', '검정콩조림', '포기김치'], ['모닝롤/롤케이크', '우유/주스', '계란후라이', '흑임자죽/쌀밥', '황태국', '미역줄기볶음', '포기김치'], ['모닝롤/에그샌드', '우유/주스', '계란후라이', '해물죽/쌀밥', '쇠고기무국', '브로컬리들깨찜', '포기김치'], ['모닝롤/치즈프레즐', '우유/주스', '계란후라이', '홍게살죽/쌀밥', '시래기국', '느타리호박볶음', '포기김치'], ['모닝롤/베이컨샌드', '우유/주스', '계란후라이', '브로컬리죽/쌀밥', '오징어국', '숙주나물', '포기김치'], ['모닝롤/크로와상', '우유/주스', '계란후라이', '표고버섯죽/쌀밥', '들깨미역국', '방풍나물', '포기김치'], ['모닝롤/마늘빵', '우유/주스', '계란후라이', '김치죽/쌀밥', '무채국', '김실파무침', '포기김치'], ['모닝롤/씨크립샌드', '우유/주스', '계란후라이', '참치야채죽/쌀밥', '선지해장국', '브로컬리초장', '포기김치'], ['모닝롤/카스텔라', '우유/주스', '계란후라이', '새송이버섯죽/쌀밥', '근대국', '쑥갓두부무침', '포기김치'], ['모닝롤/토마토샌드', '우유/주스', '계란후라이', '밤죽/쌀밥', '순두부국', '크랜베리멸치볶음', '포기김치'], ['모닝롤/와플', '우유/주스', '계란후라이', '견과류죽/쌀밥', '콩나물국', '진미채무침', '포기김치'], ['모닝롤/프렌치토스트', '우유/주스', '계란후라이', '새우살죽/쌀밥', '두부김치국', '미역레몬초무침', '포기김치'], ['모닝롤/참치샌드', '우유/주스', '계란후라이', '야채죽/쌀밥', '쇠고기버섯국', '오이무침', '포기김치'], ['모닝롤/핫도그', '우유/주스', '계란후라이', '닭죽/쌀밥', '감자국', '참나물무침', '포기김치'], ['모닝롤/단팥빵', '우유/주스', '계란후라이', '늙은호박죽/쌀밥', '바지락쑥국', '마늘쫑무침', '포기김치'], ['모닝롤/야채샌드', '우유/주스', '계란후라이', '녹두죽/쌀밥', '민물새우찌개', '구이김', '포기김치'], ['모닝롤/팬케익', '우유/두유/주스', '계란후라이', '잣죽/쌀밥', '근대국', '마늘쫑무침', '포기김치'], ['모닝롤/단호박샌드', '우유/두유/주스', '계란후라이', '양송이죽/쌀밥', '두부젓국찌개', '미역줄기볶음', '포기김치'], ['모닝롤/치즈프레즐', '우유/두유/주스', '계란후라이', '팥죽/쌀밥', '꽃게탕', '방풍나물', '포기김치'], ['모닝롤/치킨샌드', '우유/두유/주스', '계란후라이', '흑임자죽/쌀밥', '열무된장국', '진미채무침', '포기김치'], ['모닝롤/브라우니', '우유/두유/주스', '계란후라이', '고구마죽/쌀밥', '대구찌개', '콩조림', '포기김치'], ['모닝롤/마늘빵', '우유/두유/주스', '계란후라이', '견과류죽/쌀밥', '고추장찌개', '김자반', '포기김치'], ['모닝롤/씨크립샌드', '우유/두유/주스', '계란후라이', '쇠고기죽/쌀밥', '얼갈이된장국', '감자채볶음', '포기김치'], ['모닝롤/에그샌드', '우유/두유/주스', '계란후라이', '브로컬리죽/쌀밥', '황태국', '콩나물무침', '포기김치'], ['모닝롤/크로와상', '우유/두유/주스', '계란후라이', '새우살죽/쌀밥', '재첩국', '시금치나물', '포기김치'], ['모닝롤/꿀호떡', '우유/주스', '계란후라이', '흑임자죽/쌀밥', '감자국', '오이무침', '포기김치'], ['모닝롤/토마토샌드', '우유/주스', '계란후라이', '표고버섯죽/쌀밥', '콩나물국', '곤약어묵볶음', '포기김치'], ['모닝롤/베이글', '우유/주스', '계란후라이', '홍게살죽/쌀밥', '김치국', '느타리볶음', '포기김치'], ['모닝롤/고구마샌드', '우유/주스', '계란후라이', '늙은호박죽/쌀밥', '선지해장국', '비름나물', '포기김치'], ['모닝롤/카스텔라', '우유/주스', '계란후라이', '고구마죽/쌀밥', '아욱국', '숙주나물', '포기김치'], ['모닝롤/프렌치토스트', '우유/주스', '계란후라이', '땅콩죽/쌀밥', '차돌박이찌개', '김구이', '포기김치'], ['모닝롤/베이컨샌드', '우유/주스', '계란후라이', '녹두죽/쌀밥', '연두부탕', '열무나물', '포기김치'], ['모닝롤/와플', '우유/주스', '계란후라이', '닭죽/쌀밥', '매운어묵국', '감자채볶음', ...

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors

# load embedding model
#from gensim.models import fasttext
import fasttext
import pickle

def split_str(s):
    s = s.split(" ")
    return s

menus = ["조식메뉴", "중식메뉴", "석식메뉴"]
foods = []
for menu in menus:
    foods += train_merge[menu].apply(split_str).to_list()

filePath = './foods.txt'
foods = [list(set(f)) for f in foods]

model = 0
with open(filePath, 'wb') as lf:
    pickle.dump(foods, lf)

# with open(filePath, 'rb') as lf:
#     readList = pickle.load(lf)
#     model = fasttext.train_unsupervised(readList)
try:
    model.load_model("fast_text_models/foods.bin")
except:
    model = fasttext.train_unsupervised(input = 'foods.txt', model = 'skipgram', dim = 300, epoch = 1000)
    model.save_model("fast_text_models/foods.bin")

# %%
# # word2vec
# TRAIN_W2V = True
# model = 0
# try:
#     model = Word2Vec.load('food_embedding.model')
#     print("Model loaded")
# except:
#     if TRAIN_W2V:
#         print("Training w2v")
#         model = Word2Vec(sentences= foods, size = 300, window = 4, min_count = 0, workers = 4)
#         model.save('food_embedding.model')
#     else:
#         print("Model loading failed. Do not train.")

# %%
# w2v demo
#model.wv.most_similar("된장찌개")

# %%
when = ["조식", "중식", "석식"]
sub_menus = ["밥/빵/죽/국수/닝롤/게티/이스/우동/찌개/탕/국/스프/계장/개장/우유/두유/주스/르트/음료/러드/피클/생채/쌈", 
             "나머지"]

def dish_split_breakfast(s):
    s = s.split()
    global sub_menus
    l = {"조식/" + sm : [] for sm in sub_menus}
    for ss in s:
        chk = False
        for cateogory in l:
            for c in cateogory.split("/"):
                if c in ss[-2:]:
                    l[cateogory].append(ss)
                    chk = True
                    break
            if chk:
                break
        if not chk:
            l["조식/나머지"].append(ss)
    
    for key in l:
        l[key] = ' '.join(l[key])
        
    return l

def dish_split_lunch(s):
    s = s.split()
    global sub_menus
    l = {"중식/" + sm : [] for sm in sub_menus}
    for ss in s:
        chk = False
        for cateogory in l:
            for c in cateogory.split("/"):
                if c in ss[-2:]:
                    l[cateogory].append(ss)
                    chk = True
                    break
            if chk:
                break
        if not chk:
            l["중식/나머지"].append(ss)
    
    for key in l:
        l[key] = ' '.join(l[key])
    return l

def dish_split_dinner(s):
    s = s.split()
    global sub_menus
    l = {"석식/" + sm : [] for sm in sub_menus}
    for ss in s:
        chk = False
        for cateogory in l:
            for c in cateogory.split("/"):
                if c in ss[-2:]:
                    l[cateogory].append(ss)
                    chk = True
                    break
            if chk:
                break
        if not chk:
            l["석식/나머지"].append(ss)
    
    for key in l:
        l[key] = ' '.join(l[key])
    return l

train_merge["조식메뉴"] = train_merge["조식메뉴"].apply(dish_split_breakfast)
test_merge["조식메뉴"] = test_merge["조식메뉴"].apply(dish_split_breakfast)

train_merge["중식메뉴"] = train_merge["중식메뉴"].apply(dish_split_lunch)
test_merge["중식메뉴"] = test_merge["중식메뉴"].apply(dish_split_lunch)

train_merge["석식메뉴"] = train_merge["석식메뉴"].apply(dish_split_dinner)
test_merge["석식메뉴"] = test_merge["석식메뉴"].apply(dish_split_dinner)

train_merge

# %%
menus = ["조식메뉴", "중식메뉴", "석식메뉴"]
# Convert the column of stringified dicts to dicts
# skip this line, if the column contains dicts
for menu in menus:
    train_merge = pd.concat([train_merge, train_merge[menu].apply(pd.Series)], axis = 1).drop(menu, axis = 1)
    test_merge = pd.concat([test_merge, test_merge[menu].apply(pd.Series)], axis = 1).drop(menu, axis = 1)

# %%
def embedding(s):
    return model[s]

when = ["조식", "중식", "석식"]
sub_menus = ["밥/빵/죽/국수/닝롤/게티/이스/우동/찌개/탕/국/스프/계장/개장/우유/두유/주스/르트/음료/러드/피클/생채/쌈", 
             "나머지"]
for w in when:
    for sm in sub_menus:
        train_merge[w + "/" + sm] = train_merge[w + "/" + sm].apply(embedding)
        test_merge[w + "/" + sm] = test_merge[w + "/" + sm].apply(embedding)
   
# word2vec
# for menu in menus:
#     for sm in sub_menus:
#         train_merge[menu + "_" + sm] = train_merge[menu].apply(dish_split)
#         test_merge[menu] = test_merge[menu].apply(dish_split)

train_merge
# Out:
#       본사시간외근무명령서승인건수     중식계    석식계  휴일전후날여부_0.0  휴일전후날여부_1.0  본사실근무자수  요일_금  \
# 0                238  1039.0  331.0            1            0   2476.0     0
# 1                319   867.0  560.0            1            0   2464.5     0
# 2                111  1017.0  573.0            1            0   2455.0     0
# 3                355   978.0  525.0            1            0   2387.0     0
# 4                 34   925.0  330.0            1            0   2232.5     1
# ...              ...     ...    ...          ...          ...      ...   ...
# 1201               4  1093.0  421.0            1            0   2418.0     0
# 1202             462   832.0  353.0            1            0   2424.5     0
# 1203               1   579.0  217.0            1            0   2301.0     1
# 1204             616  1145.0  502.0            1            0   2472.5     0
# 1205             551  1015.0  480.0            1            0   2460.5     0
#
#       요일_목  요일_수  요일_월  요일_화  \
# 0        0     0     1     0
# 1        0     0     0     1
# 2        0     1     0     0
# 3        1     0     0     0
# 4        0     0     0     0
# ...    ...   ...   ...   ...
# 1201     0     1     0     0
# 1202     1     0     0     0
# 1203     0     0     0     0
# 1204     0     0     1     0
# 1205     0     0     0     1
#
#      조식/밥/빵/죽/국수/닝롤/게티/이스/우동/찌개/탕/국/스프/계장/개장/우유/두유/주스/르트/음료/러드/피클/생채/쌈  \
# 0     [-0.016936077, -0.014553572, -0.00080621254, 0...
# 1     [-0.024015496, -0.0064924, -0.0012554897, -0.0...
# 2     [-0.0017852286, -0.010965817, 0.010012273, -0....
# 3     [-0.0051323636, -0.014993706, 0.017068371, -0....
# 4     [-0.0035292765, -0.010291563, 0.007849957, -0....
# ...                                                 ...
# 1201  [-0.011243458, -0.0018707602, -0.009175199, -0...
# 1202  [-0.014909329, -0.005105199, -0.023776041, 0.0...
# 1203  [0.008407472, -0.006849909, 0.017067358, -0.01...
# 1204  [-0.0067526703, -0.006425758, -0.026725922, 0....
# 1205  [-0.011277148, -0.0015963404, -0.0094896825, -...
#
#                                                  조식/나머지  \
# 0     [-0.0041844225, -8.0393065e-06, -0.015162784, ...
# 1     [-0.021263966, -0.014365483, 0.004407744, 0.00...
# 2     [-0.045467377, -0.018072166, -0.043939818, -0....
# 3     [-0.034240413, -0.0061479923, -0.014103845, 0....
# 4     [-0.02326852, -0.00937635, -0.020493621, 0.000...
# ...                                                 ...
# 1201  [-0.013902255, -0.005282051, -0.012052029, 7.1...
# 1202  [-0.004787934, -0.00056122534, -0.014468682, -...
# 1203  [-0.016037168, -0.007201577, -0.013762738, -0....
# 1204  [-0.011850159, -0.0057645445, -0.01226853, 8.1...
# 1205  [-0.028278628, -0.0064965743, -0.024546737, -0...
#
#      중식/밥/빵/죽/국수/닝롤/게티/이스/우동/찌개/탕/국/스프/계장/개장/우유/두유/주스/르트/음료/러드/피클/생채/쌈  \
# 0     [-0.00048093504, 0.00095220096, 0.002996142, -...
# 1     [0.00012448526, -8.740279e-05, 0.00036670166, ...
# 2     [1.1690046e-05, 0.0006352126, -0.00012261949, ...
# 3     [-9.5099684e-05, 0.00017896495, 0.00020475664,...
# 4     [0.00017659593, 0.00013278783, 0.0004027581, -...
# ...                                                 ...
# 1201  [-0.0037891776, 0.011898914, -0.012174187, -0....
# 1202  [-0.003663061, 0.009963849, -0.009310928, -0.0...
# 1203  [-0.006895758, 0.016342826, -0.015454275, -0.0...
# 1204  [-0.0028328802, 0.008300606, -0.0071078204, -0...
# 1205  [0.000987483, 0.0014863602, 0.00096841523, -0....
#
#                                                  중식/나머지  \
# 0     [0.0022547054, 0.00064308237, 0.003949783, -0....
# 1     [2.4493182e-05, -0.0001197532, -6.0511225e-05,...
# 2     [0.0021536872, 0.0004988377, 0.0038399992, -0....
# 3     [0.0023268303, 0.00044028956, 0.0036611573, -0...
# 4     [0.0021933757, 0.00076024694, 0.003849344, -0....
# ...                                                 ...
# 1201  [5.1342464e-05, -0.00027197105, 6.3935055e-05,...
# 1202  [0.00034176523, 0.00022855774, 7.452242e-05, -...
# 1203  [0.0015101995, 0.00019271777, 0.0022535452, -0...
# 1204  [-4.0418912e-05, -2.3652216e-05, -8.397373e-05...
# 1205  [-4.5995228e-05, -0.0006647313, 0.00020408683,...
#
#      석식/밥/빵/죽/국수/닝롤/게티/이스/우동/찌개/탕/국/스프/계장/개장/우유/두유/주스/르트/음료/러드/피클/생채/쌈  \
# 0     [-0.00025498657, -0.00061500724, 0.00023055589...
# 1     [0.014501365, -0.017793734, 0.026160067, -0.01...
# 2     [-0.00061588595, 6.299102e-05, 0.00046757283, ...
# 3     [-2.5005955e-05, -3.4473753e-05, -3.647806e-05...
# 4     [-0.00020652119, -0.000106880616, 0.0001232694...
# ...                                                 ...
# 1201  [-0.00077359716, 0.0038560852, -0.0034477843, ...
# 1202  [0.0003035021, 0.00023830833, -0.0002055001, -...
# 1203  [-0.00028159804, -0.00033226403, 0.00044086372...
# 1204  [-0.0103260735, -0.01784892, -0.014615008, 1.0...
# 1205  [0.0005013046, -7.594377e-07, -0.00024120351, ...
#
#                                                  석식/나머지
# 0     [0.002174928, -0.00036696077, 0.0037201685, -0...
# 1     [-0.004985391, 0.011282488, -0.017811505, -0.0...
# 2     [0.0010696593, 0.0005745198, 0.0030431144, -0....
# 3     [0.006649643, -0.0025989173, 0.0034942941, -0....
# 4     [0.0034404192, -0.0011005967, 0.0060540168, -0...
# ...                                                 ...
# 1201  [-0.0029396552, -0.0003935999, -0.009593778, 0...
# 1202  [0.001497007, 0.00063274836, 0.0023831092, -0....
# 1203  [-4.3768273e-06, 4.4051416e-05, -0.00010854615...
# 1204  [0.0018041873, 0.00016818642, 0.0030980217, -0...
# 1205  [0.0016406964, 0.0026796104, -0.00461622, -0.0...
#
# [1206 rows x 17 columns]

# %%
# seperate each vecs to new cols

for w in when:
    for sm in sub_menus:
        tmp_col = w + "/" + sm
        tmp = [tmp_col + str(i) for i in range(300)]
        train_merge[tmp] = pd.DataFrame(train_merge[tmp_col].to_list(), columns = tmp)
        test_merge[tmp] = pd.DataFrame(test_merge[tmp_col].to_list(), columns = tmp)
        train_merge.drop([tmp_col], inplace = True, axis = 1)
        test_merge.drop([tmp_col], inplace = True, axis = 1)

train_merge
# Out:
#       본사시간외근무명령서승인건수     중식계    석식계  휴일전후날여부_0.0  휴일전후날여부_1.0  본사실근무자수  요일_금  \
# 0                238  1039.0  331.0            1            0   2476.0     0
# 1                319   867.0  560.0            1            0   2464.5     0
# 2                111  1017.0  573.0            1            0   2455.0     0
# 3                355   978.0  525.0            1            0   2387.0     0
# 4                 34   925.0  330.0            1            0   2232.5     1
# ...              ...     ...    ...          ...          ...      ...   ...
# 1201               4  1093.0  421.0            1            0   2418.0     0
# 1202             462   832.0  353.0            1            0   2424.5     0
# 1203               1   579.0  217.0            1            0   2301.0     1
# 1204             616  1145.0  502.0            1            0   2472.5     0
# 1205             551  1015.0  480.0            1            0   2460.5     0
#
#       요일_목  요일_수  요일_월  ...  석식/나머지290  석식/나머지291  석식/나머지292  석식/나머지293  \
# 0        0     0     1  ...   0.000935  -0.001000   0.000449  -0.000863
# 1        0     0     0  ...  -0.003620  -0.008728   0.002187   0.002295
# 2        0     1     0  ...   0.006517  -0.000648  -0.001448   0.000453
# 3        1     0     0  ...  -0.006870  -0.001154   0.001284  -0.008485
# 4        0     0     0  ...  -0.004906   0.000134  -0.000325  -0.000381
# ...    ...   ...   ...  ...        ...        ...        ...        ...
# 1201     0     1     0  ...   0.008119  -0.002500  -0.003218   0.001360
# 1202     1     0     0  ...   0.000088  -0.000608   0.000122  -0.000355
# 1203     0     0     0  ...   0.000247  -0.000081   0.000053  -0.000155
# 1204     0     0     1  ...   0.000122  -0.001120   0.000347  -0.000186
# 1205     0     0     0  ...   0.011422  -0.001217   0.002583  -0.002107
#
#       석식/나머지294  석식/나머지295  석식/나머지296  석식/나머지297  석식/나머지298  석식/나머지299
# 0     -0.003221   0.000298  -0.002273  -0.003964   0.000374   0.003159
# 1      0.014928   0.002293   0.009973   0.007330  -0.034300   0.067998
# 2     -0.003922  -0.000138   0.005141   0.002455   0.000703   0.000405
# 3     -0.011142  -0.002888  -0.002892  -0.009153   0.010763  -0.008266
# 4     -0.000518  -0.001354  -0.001355  -0.003898   0.003843  -0.001032
# ...         ...        ...        ...        ...        ...        ...
# 1201   0.002582  -0.001179   0.000032   0.009817  -0.003788   0.008490
# 1202   0.000696   0.000007   0.000348  -0.000587   0.001744   0.001108
# 1203   0.000165  -0.000233   0.000053  -0.000145  -0.000099   0.000146
# 1204   0.000649  -0.000133   0.000375  -0.000958   0.001908   0.001138
# 1205   0.013136  -0.005062  -0.004643   0.012248  -0.003934   0.017085
#
# [1206 rows x 1811 columns]

# %%
from sklearn.decomposition import PCA

# PCA 300 -> 20
pca_target = 20
pca = PCA(n_components = pca_target)
for w in when:
    for sm in sub_menus:
        tmp_col = w + "/" + sm
        tmp = [tmp_col + str(i) for i in range(300)]
        target = [tmp_col + "_pca" + str(i) for i in range(pca_target)]
        train_merge[target] = pca.fit_transform(train_merge[tmp])
        test_merge[target] = pca.fit_transform(test_merge[tmp])
        
# del cols before PCA

for w in when:
    for sm in sub_menus:
        tmp_col = w + "/" + sm
        tmp = [tmp_col + str(i) for i in range(300)]
        train_merge.drop(tmp, inplace = True, axis = 1)
        test_merge.drop(tmp, inplace = True, axis = 1)
        
train_merge.head()
# Out:
#    본사시간외근무명령서승인건수     중식계    석식계  휴일전후날여부_0.0  휴일전후날여부_1.0  본사실근무자수  요일_금  \
# 0             238  1039.0  331.0            1            0   2476.0     0
# 1             319   867.0  560.0            1            0   2464.5     0
# 2             111  1017.0  573.0            1            0   2455.0     0
# 3             355   978.0  525.0            1            0   2387.0     0
# 4              34   925.0  330.0            1            0   2232.5     1
#
#    요일_목  요일_수  요일_월  ...  석식/나머지_pca10  석식/나머지_pca11  석식/나머지_pca12  \
# 0     0     0     1  ...      0.003524      0.001131      0.001548
# 1     0     0     0  ...     -0.001247      0.000858      0.002325
# 2     0     1     0  ...     -0.006989     -0.006255     -0.005522
# 3     1     0     0  ...      0.007394     -0.000807      0.005130
# 4     0     0     0  ...     -0.000239      0.003819     -0.001206
#
#    석식/나머지_pca13  석식/나머지_pca14  석식/나머지_pca15  석식/나머지_pca16  석식/나머지_pca17  \
# 0      0.002783      0.000631     -0.003606      0.002254     -0.000916
# 1      0.002459     -0.000284      0.000570     -0.000146      0.000214
# 2     -0.001265     -0.007477     -0.011848     -0.008446     -0.002697
# 3     -0.001438     -0.000240      0.001917      0.001574     -0.001779
# 4      0.003506      0.000967      0.002107      0.001072     -0.000168
#
#    석식/나머지_pca18  석식/나머지_pca19
# 0      0.004350      0.006975
# 1     -0.001558      0.000883
# 2     -0.004626      0.003375
# 3      0.002077     -0.002325
# 4      0.000427      0.000178
#
# [5 rows x 131 columns]

# %%
from sklearn.preprocessing import RobustScaler

target = []

for w in when:
    for sm in sub_menus:
        tmp_col = w + "/" + sm
        target += [tmp_col + "_pca" + str(i) for i in range(pca_target)]
        
scaled = ["본사시간외근무명령서승인건수", 
          #"최저기온(°C)", "평균기온(°C)", "최고기온(°C)", "평균 풍속(m/s)", 
          #"최대 풍속(m/s)", "일강수량(mm)", 
          "본사실근무자수"] + target
train_merge[scaled] = RobustScaler().fit_transform(train_merge[scaled].values)
test_merge[scaled] = RobustScaler().fit_transform(test_merge[scaled].values)

# %%
train_merge
# Out:
#       본사시간외근무명령서승인건수     중식계    석식계  휴일전후날여부_0.0  휴일전후날여부_1.0   본사실근무자수  요일_금  \
# 0          -0.135045  1039.0  331.0            1            0  0.011315     0
# 1           0.045759   867.0  560.0            1            0 -0.053748     0
# 2          -0.418527  1017.0  573.0            1            0 -0.107496     0
# 3           0.126116   978.0  525.0            1            0 -0.492221     0
# 4          -0.590402   925.0  330.0            1            0 -1.366337     1
# ...              ...     ...    ...          ...          ...       ...   ...
# 1201       -0.657366  1093.0  421.0            1            0 -0.316832     0
# 1202        0.364955   832.0  353.0            1            0 -0.280057     0
# 1203       -0.664062   579.0  217.0            1            0 -0.978784     1
# 1204        0.708705  1145.0  502.0            1            0 -0.008487     0
# 1205        0.563616  1015.0  480.0            1            0 -0.076379     0
#
#       요일_목  요일_수  요일_월  ...  석식/나머지_pca10  석식/나머지_pca11  석식/나머지_pca12  \
# 0        0     0     1  ...      6.863906      4.929184      0.910665
# 1        0     0     0  ...     -3.591156      4.329494      1.266218
# 2        0     1     0  ...    -16.172848    -11.344194     -2.323415
# 3        1     0     0  ...     15.342328      0.660568      2.549560
# 4        0     0     0  ...     -1.381725     10.852030     -0.349064
# ...    ...   ...   ...  ...           ...           ...           ...
# 1201     0     1     0  ...      1.919077      5.860018      2.569952
# 1202     1     0     0  ...     -0.440825     -0.572366     -0.190196
# 1203     0     0     0  ...      0.314187      1.125663     -0.713172
# 1204     0     0     1  ...     -0.465201      0.292808     -0.101555
# 1205     0     0     0  ...     17.410143     26.354411     -9.707704
#
#       석식/나머지_pca13  석식/나머지_pca14  석식/나머지_pca15  석식/나머지_pca16  석식/나머지_pca17  \
# 0         3.511577      0.243905     -4.822193      4.808351     -1.010342
# 1         3.121614     -0.812770      0.477713      0.555823      1.459380
# 2        -1.364279     -9.121355    -15.281630    -14.145578     -4.901904
# 3        -1.572656     -0.761560      2.187058      3.602591     -2.895519
# 4         4.382744      0.632412      2.429071      2.713857      0.625194
# ...            ...           ...           ...           ...           ...
# 1201      1.922903    -10.043321     -1.549729      5.414987    -11.708099
# 1202      0.037018      0.169844      0.136346      0.063866      0.037375
# 1203     -0.604635     -0.490364     -1.090888     -0.195410     -0.125652
# 1204      0.195668     -0.436490      0.385846     -0.262620      0.018194
# 1205     31.444220     10.362719      1.789045     18.394137     31.923251
#
#       석식/나머지_pca18  석식/나머지_pca19
# 0        11.109403     14.276291
# 1        -4.545690      1.499453
# 2       -12.674327      6.725583
# 3         5.086248     -5.229257
# 4         0.715319      0.021246
# ...            ...           ...
# 1201      2.744224      7.724370
# 1202     -0.523617      0.049923
# 1203      0.236704     -0.329461
# 1204      0.025283     -0.429465
# 1205    -28.051536     54.046407
#
# [1206 rows x 131 columns]

# %%
from sklearn.preprocessing import StandardScaler

# std scaling embedded vecs

# scaled_menus_train = {}
# scaled_menus_test = {}

# menus = ["조식메뉴", "중식메뉴", "석식메뉴"]

# for menu in menus:
#     scaled_menus_train[menu] = StandardScaler().fit_transform(train_merge[menu].to_list())
#     scaled_menus_test[menu] = StandardScaler().fit_transform(test_merge[menu].to_list())
#     for idx, val in enumerate(scaled_menus_train[menu]):
#         train_merge[menu][idx] = val
#     for idx, val in enumerate(scaled_menus_test[menu]):
#         test_merge[menu][idx] = val

# %%
import pandas_profiling
from pandas_profiling import ProfileReport

# profile = train_merge[["본사시간외근무명령서승인건수", "중식계", "석식계", "최저기온(°C)", "평균기온(°C)", 
#                               "최고기온(°C)", "평균 풍속(m/s)", "최대 풍속(m/s)", "일강수량(mm)", "휴일전후날여부_0.0", "휴일전후날여부_1.0"]].profile_report()
# profile

# %%
train_merge.head()
# Out:
#    본사시간외근무명령서승인건수     중식계    석식계  휴일전후날여부_0.0  휴일전후날여부_1.0   본사실근무자수  요일_금  \
# 0       -0.135045  1039.0  331.0            1            0  0.011315     0
# 1        0.045759   867.0  560.0            1            0 -0.053748     0
# 2       -0.418527  1017.0  573.0            1            0 -0.107496     0
# 3        0.126116   978.0  525.0            1            0 -0.492221     0
# 4       -0.590402   925.0  330.0            1            0 -1.366337     1
#
#    요일_목  요일_수  요일_월  ...  석식/나머지_pca10  석식/나머지_pca11  석식/나머지_pca12  \
# 0     0     0     1  ...      6.863906      4.929184      0.910665
# 1     0     0     0  ...     -3.591156      4.329494      1.266218
# 2     0     1     0  ...    -16.172848    -11.344194     -2.323415
# 3     1     0     0  ...     15.342328      0.660568      2.549560
# 4     0     0     0  ...     -1.381725     10.852030     -0.349064
#
#    석식/나머지_pca13  석식/나머지_pca14  석식/나머지_pca15  석식/나머지_pca16  석식/나머지_pca17  \
# 0      3.511577      0.243905     -4.822193      4.808351     -1.010342
# 1      3.121614     -0.812770      0.477713      0.555823      1.459380
# 2     -1.364279     -9.121355    -15.281630    -14.145578     -4.901904
# 3     -1.572656     -0.761560      2.187058      3.602591     -2.895519
# 4      4.382744      0.632412      2.429071      2.713857      0.625194
#
#    석식/나머지_pca18  석식/나머지_pca19
# 0     11.109403     14.276291
# 1     -4.545690      1.499453
# 2    -12.674327      6.725583
# 3      5.086248     -5.229257
# 4      0.715319      0.021246
#
# [5 rows x 131 columns]

# %%
from pycaret.regression import *

when = ["조식", "중식", "석식"]
sub_menus = ["밥/빵/죽/국수/닝롤/게티/이스/우동", 
             "찌개/탕/국/스프/계장/개장", 
             "우유/두유/주스/음료", 
             "무침/자반/잡채/나물",
             "강정/튀김/가스",
             "조림/볶음/구이/고기", 
             "김치/깍두기/박지/절이", 
             "러드/피클/생채", 
             "나머지"]

exp_lunch = setup(train_merge, target = '중식계',
                 imputation_type='iterative',
                  ignore_features = ["일자"],
                 remove_perfect_collinearity = False,
                 )

# %%
best_4_lunch = compare_models(sort = 'MAE', n_select = 4)

# %%
blended_lunch = blend_models(estimator_list = best_4_lunch, fold = 5)

# %%
prediction_lunch = predict_model(blended_lunch)

# %%
final_lunch = finalize_model(blended_lunch)

# %%
final_prediction_lunch = predict_model(final_lunch, data = test_merge)

# %%
submission["중식계"] = final_prediction_lunch["Label"]

# %%
from pycaret.regression import *
exp_dinner = setup(train_merge, target = '석식계', 
                   ignore_features = ['중식계'])

# %%
best_4_dinner = compare_models(sort = 'MAE', n_select = 4)

# %%
blended_dinner = blend_models(estimator_list = best_4_dinner, fold = 5)

# %%
prediction_dinner = predict_model(blended_dinner)

# %%
final_dinner = finalize_model(blended_dinner)

# %%
final_prediction_dinner = predict_model(final_dinner, data = test_merge)

# %%
submission["석식계"] = final_prediction_dinner["Label"]

# %%
submission.head(20)

# %%
submission.to_csv('submission_성동현.csv', index = False, encoding = "UTF-8")

# %%
test.head(20)

# %%
list(train_merge.columns)

# %%
from sklearn.metrics import mean_absolute_error
from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.simplefilter(action = 'ignore')

# %%
train_lunch = train_merge['중식계']
train_dinner = train_merge['석식계']

lunch_features = [s for s in train_merge.columns if "중식" in s and "중식계" not in s]
dinner_features = [s for s in train_merge.columns if "석식" in s and "석식계" not in s]

train_lunch_features = train_merge.drop(['중식계', '석식계'] + dinner_features, axis=1)
train_dinner_features = train_merge.drop(['중식계', '석식계'] + lunch_features, axis=1)

test_lunch_features = test_merge.drop(dinner_features, axis=1)
test_dinner_features = test_merge.drop(lunch_features, axis=1)

# %%
def print_best_params(model, params, train, train_features):
    grid_model = GridSearchCV(
        model, 
        param_grid = params,
        verbose = 4,
        cv = 5,
        scoring = 'neg_mean_absolute_error')

    grid_model.fit(train_features, train)
    score = -1 * grid_model.best_score_ # mae
    print(
        '{0} 5 CV 시 최적 평균 MAE 값 {1} \n최적 alpha:{2}'.format(model.__class__.__name__, np.round(score, 4), grid_model.best_params_))
    return grid_model.best_estimator_

# %%
# Simple LGBM Regressor w/o tuning

lgb_params_lunch = {
    'metric' : ['mae'],
    'objective':['mae'],
    'max_depth' : [10 + i for i in range(0, 8, 2)],
    'learning_rate' : [0.015, 0.020],
    'n_estimators':[600 + i for i in range(0, 300, 100)],
    'max_bin' : [400 + i for i in range(0, 250, 100)],
}

# %%
lgb_model_lunch = LGBMRegressor()
lgb_estimator_lunch = print_best_params(lgb_model_lunch, lgb_params_lunch, train_lunch, train_lunch_features)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-96.365 total time=   2.3s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-82.985 total time=   2.5s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-94.252 total time=   2.3s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-108.706 total time=   1.7s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-115.188 total time=   1.8s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-95.585 total time=   2.2s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-82.890 total time=   2.1s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-93.996 total time=   2.0s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-109.029 total time=   2.1s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-114.951 total time=   2.2s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-95.747 total time=   2.9s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-83.163 total time=   2.9s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-93.815 total time=   2.9s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-109.815 total time=   2.9s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-114.927 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-98.459 total time=   2.3s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-81.785 total time=   2.3s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-93.201 total time=   2.5s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-109.630 total time=   2.0s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-115.911 total time=   1.8s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-96.873 total time=   2.1s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-81.359 total time=   2.1s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-92.982 total time=   2.2s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-108.635 total time=   2.2s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-115.801 total time=   2.1s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-96.141 total time=   2.4s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-81.321 total time=   2.5s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-93.075 total time=   2.7s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-109.278 total time=   3.2s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-115.350 total time=   3.2s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-93.342 total time=   2.2s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-82.954 total time=   2.2s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-93.560 total time=   2.2s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-109.225 total time=   2.2s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-115.929 total time=   2.1s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-93.807 total time=   2.6s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-82.620 total time=   2.6s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-93.669 total time=   2.6s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-110.473 total time=   2.6s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-114.506 total time=   2.5s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-95.754 total time=   3.0s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-82.218 total time=   3.0s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-93.678 total time=   2.9s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-110.979 total time=   3.0s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-114.138 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-95.487 total time=   2.2s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-83.386 total time=   2.2s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-94.031 total time=   2.1s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-110.113 total time=   1.9s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-115.924 total time=   1.9s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-96.588 total time=   2.1s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-83.805 total time=   2.2s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-93.603 total time=   2.9s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-110.990 total time=   2.6s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-115.335 total time=   2.6s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-96.981 total time=   3.0s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-83.925 total time=   2.9s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-93.653 total time=   3.0s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-111.148 total time=   3.2s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-115.228 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-96.403 total time=   2.0s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-82.534 total time=   2.1s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-93.830 total time=   2.1s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-109.464 total time=   2.1s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-115.184 total time=   2.0s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-96.254 total time=   2.5s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-82.603 total time=   2.5s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-93.465 total time=   2.4s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-109.913 total time=   2.3s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-114.990 total time=   2.5s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-95.410 total time=   2.7s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-82.548 total time=   2.8s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-93.517 total time=   2.3s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-110.988 total time=   2.2s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-114.500 total time=   2.3s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-94.353 total time=   1.8s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-83.587 total time=   1.8s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-94.490 total time=   1.8s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-109.545 total time=   1.7s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-116.495 total time=   1.5s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-96.032 total time=   1.9s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-82.740 total time=   2.3s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-94.718 total time=   2.4s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-109.329 total time=   2.4s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-115.452 total time=   2.4s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-96.802 total time=   3.0s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-82.613 total time=   2.9s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-94.934 total time=   2.8s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-109.852 total time=   2.9s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-115.039 total time=   2.8s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-96.149 total time=   2.1s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-83.331 total time=   2.1s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-93.608 total time=   2.2s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-109.775 total time=   2.1s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-115.484 total time=   2.1s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-95.202 total time=   2.6s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-83.458 total time=   2.7s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-93.271 total time=   2.5s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-110.898 total time=   2.5s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-115.065 total time=   2.5s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-95.637 total time=   2.8s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-83.467 total time=   2.9s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-93.394 total time=   2.9s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-111.241 total time=   2.8s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-114.946 total time=   2.7s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-97.474 total time=   2.1s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-83.460 total time=   2.3s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-93.550 total time=   2.5s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-109.228 total time=   2.2s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-116.104 total time=   2.3s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-97.057 total time=   2.4s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-83.639 total time=   2.5s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-93.526 total time=   2.6s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-110.684 total time=   2.6s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-116.091 total time=   2.7s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-95.246 total time=   2.9s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-83.702 total time=   2.6s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-93.590 total time=   2.6s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-111.356 total time=   2.3s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-115.143 total time=   2.3s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-98.289 total time=   1.6s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-83.489 total time=   1.6s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-94.288 total time=   1.9s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-111.072 total time=   1.7s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-115.792 total time=   1.9s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-96.627 total time=   1.5s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-83.445 total time=   1.4s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-94.322 total time=   1.4s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-109.771 total time=   1.4s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-115.092 total time=   1.4s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-95.468 total time=   1.6s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-83.444 total time=   1.7s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-94.234 total time=   1.6s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-109.636 total time=   1.7s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-114.999 total time=   1.6s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-96.525 total time=   1.3s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-84.280 total time=   1.3s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-94.557 total time=   1.3s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-109.927 total time=   1.3s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-115.759 total time=   1.3s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-96.104 total time=   1.5s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-84.387 total time=   1.5s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-93.989 total time=   1.5s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-110.009 total time=   1.5s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-115.393 total time=   1.5s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-96.352 total time=   1.9s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-84.275 total time=   2.6s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-93.776 total time=   2.9s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-109.243 total time=   2.8s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-114.163 total time=   2.8s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-95.327 total time=   2.1s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-81.917 total time=   2.1s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-94.422 total time=   2.1s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-108.061 total time=   2.1s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-115.529 total time=   3.2s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-95.441 total time=   1.9s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-81.721 total time=   2.1s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-94.304 total time=   2.0s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-109.766 total time=   1.9s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-115.348 total time=   1.9s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-96.665 total time=   2.2s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-81.743 total time=   2.3s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-94.070 total time=   2.7s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-110.088 total time=   2.7s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-115.278 total time=   2.8s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-97.446 total time=   2.0s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-81.736 total time=   2.1s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-94.196 total time=   2.0s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-109.480 total time=   2.1s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-115.798 total time=   2.1s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-95.570 total time=   2.5s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-81.620 total time=   2.5s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-94.020 total time=   2.7s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-110.601 total time=   2.4s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-115.750 total time=   2.4s
# [CV 1/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-95.756 total time=   2.8s
# [CV 2/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-81.540 total time=   2.9s
# [CV 3/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-94.205 total time=   3.2s
# [CV 4/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-110.705 total time=   2.8s
# [CV 5/5] END learning_rate=0.015, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-114.630 total time=   2.6s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-95.645 total time=   1.7s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-83.358 total time=   1.7s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-95.187 total time=   1.7s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-111.356 total time=   1.7s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-115.697 total time=   1.7s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-95.070 total time=   1.9s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-82.966 total time=   2.2s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-94.947 total time=   2.2s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-111.633 total time=   2.3s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-115.681 total time=   2.4s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-95.204 total time=   2.9s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-83.074 total time=   2.8s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-94.251 total time=   2.6s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-110.858 total time=   2.2s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-114.980 total time=   2.1s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-97.382 total time=   1.7s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-82.373 total time=   1.8s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-95.196 total time=   1.8s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-111.442 total time=   1.8s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-115.005 total time=   1.8s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-97.076 total time=   2.0s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-81.964 total time=   2.6s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-95.146 total time=   2.5s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-111.254 total time=   2.5s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-114.986 total time=   2.4s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-95.924 total time=   2.8s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-81.734 total time=   2.8s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-94.683 total time=   2.9s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-110.696 total time=   2.9s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-113.882 total time=   2.9s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-94.244 total time=   2.3s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-82.770 total time=   1.9s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-94.876 total time=   1.7s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-109.209 total time=   1.7s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-116.050 total time=   1.8s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-94.883 total time=   2.1s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-82.695 total time=   2.3s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-94.835 total time=   2.0s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-110.477 total time=   2.1s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-115.885 total time=   2.1s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-95.680 total time=   2.3s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-82.235 total time=   2.9s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-94.304 total time=   2.9s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-110.493 total time=   2.9s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-115.079 total time=   2.8s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-94.495 total time=   2.2s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-81.899 total time=   2.3s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-93.732 total time=   2.3s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-111.219 total time=   2.3s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-115.102 total time=   2.1s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-94.753 total time=   2.7s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-81.685 total time=   2.6s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-93.766 total time=   3.1s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-111.511 total time=   2.6s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-115.045 total time=   2.5s
# [CV 1/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-95.649 total time=   3.0s
# [CV 2/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-81.309 total time=   3.3s
# [CV 3/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-93.756 total time=   3.0s
# [CV 4/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-111.923 total time=   3.0s
# [CV 5/5] END learning_rate=0.02, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-114.896 total time=   2.7s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-96.017 total time=   1.6s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-82.354 total time=   1.9s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-94.987 total time=   1.6s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-109.962 total time=   1.6s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-115.219 total time=   1.6s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-96.730 total time=   1.9s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-82.220 total time=   2.0s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-95.008 total time=   1.9s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-110.749 total time=   2.2s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-114.435 total time=   2.3s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-96.720 total time=   2.6s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-82.072 total time=   3.2s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-94.476 total time=   3.0s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-111.128 total time=   2.9s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-114.259 total time=   2.8s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-99.520 total time=   2.2s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-83.367 total time=   2.3s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-93.726 total time=   2.3s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-111.053 total time=   2.3s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-115.842 total time=   2.0s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-99.159 total time=   2.0s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-82.909 total time=   2.2s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-93.748 total time=   2.0s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-111.626 total time=   2.0s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-115.547 total time=   2.0s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-97.704 total time=   2.3s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-82.673 total time=   2.3s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-93.697 total time=   2.7s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-111.945 total time=   2.8s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-115.616 total time=   2.8s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-95.457 total time=   2.2s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-81.303 total time=   2.2s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-94.650 total time=   2.2s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-109.025 total time=   2.2s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-117.366 total time=   2.2s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-95.634 total time=   2.6s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-81.429 total time=   2.6s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-94.576 total time=   2.6s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-109.744 total time=   2.6s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-116.131 total time=   2.4s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-96.871 total time=   2.4s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-81.629 total time=   2.5s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-94.234 total time=   2.4s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-110.414 total time=   2.3s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-115.942 total time=   2.3s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-97.903 total time=   2.1s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-82.054 total time=   2.2s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-94.515 total time=   2.2s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-109.050 total time=   2.3s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-115.707 total time=   2.2s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-96.220 total time=   2.7s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-82.000 total time=   2.3s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-94.433 total time=   2.1s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-109.700 total time=   2.0s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-115.185 total time=   2.0s
# [CV 1/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-95.681 total time=   2.3s
# [CV 2/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-82.148 total time=   2.3s
# [CV 3/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-93.768 total time=   2.4s
# [CV 4/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-110.779 total time=   2.3s
# [CV 5/5] END learning_rate=0.02, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-115.128 total time=   2.5s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-98.376 total time=   2.2s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-82.201 total time=   2.0s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-95.194 total time=   2.0s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-110.085 total time=   2.2s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=600, objective=mae;, score=-114.590 total time=   2.0s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-96.416 total time=   2.4s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-82.148 total time=   2.5s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-94.582 total time=   2.7s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-110.854 total time=   2.5s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=700, objective=mae;, score=-113.991 total time=   4.0s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-96.018 total time=   3.7s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-82.195 total time=   2.7s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-94.161 total time=   2.9s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-110.890 total time=   3.7s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=10, metric=mae, n_estimators=800, objective=mae;, score=-114.008 total time=   2.8s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-95.963 total time=   1.8s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-83.208 total time=   1.7s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-94.243 total time=   1.8s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-110.657 total time=   1.6s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=600, objective=mae;, score=-115.129 total time=   1.6s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-95.569 total time=   2.0s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-83.441 total time=   2.0s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-94.507 total time=   2.3s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-111.886 total time=   2.8s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=700, objective=mae;, score=-114.297 total time=   2.9s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-96.312 total time=   2.9s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-83.565 total time=   4.6s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-94.618 total time=   3.9s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-112.299 total time=   4.4s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=12, metric=mae, n_estimators=800, objective=mae;, score=-114.185 total time=   3.7s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-98.088 total time=   3.0s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-81.329 total time=   3.5s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-94.730 total time=   2.6s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-110.699 total time=   2.1s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=600, objective=mae;, score=-114.795 total time=   2.0s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-97.834 total time=   2.3s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-81.432 total time=   2.3s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-94.901 total time=   2.2s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-111.139 total time=   2.3s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=700, objective=mae;, score=-114.517 total time=   2.1s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-97.461 total time=   2.5s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-81.422 total time=   2.8s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-94.861 total time=   3.3s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-110.501 total time=   3.5s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=14, metric=mae, n_estimators=800, objective=mae;, score=-114.336 total time=   3.9s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-99.511 total time=   2.9s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-81.796 total time=   2.7s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-94.920 total time=   3.3s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-111.055 total time=   2.8s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-114.463 total time=   2.2s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-97.891 total time=   2.8s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-81.963 total time=   2.9s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-95.152 total time=   3.2s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-111.623 total time=   2.9s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-114.025 total time=   2.8s
# [CV 1/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-97.075 total time=   4.3s
# [CV 2/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-82.236 total time=   3.2s
# [CV 3/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-95.234 total time=   5.6s
# [CV 4/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-111.831 total time=   4.2s
# [CV 5/5] END learning_rate=0.02, max_bin=600, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-113.805 total time=   2.8s
# LGBMRegressor 5 CV 시 최적 평균 MAE 값 99.0018
# 최적 alpha:{'learning_rate': 0.015, 'max_bin': 400, 'max_depth': 14, 'metric': 'mae', 'n_estimators': 600, 'objective': 'mae'}

# %%
lgb_preds_lunch = lgb_estimator_lunch.predict(test_lunch_features, axis=1)

# %%
submission["중식계"] = lgb_preds_lunch

# %%
# Simple LGBM Regressor w/o tuning

lgb_params_dinner = {
    'metric' : ['mae'],
    'objective':['mae'],
    'max_depth' : [16 + i for i in range(0, 8, 2)],
    'learning_rate' : [0.015],
    'n_estimators':[600 + i for i in range(0, 300, 100)],
    'max_bin' : [400 + i for i in range(0, 200, 50)],
}

# %%
lgb_model_dinner = LGBMRegressor()
lgb_estimator_dinner = print_best_params(lgb_model_dinner, lgb_params_dinner, train_dinner, train_dinner_features)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-75.237 total time=   1.9s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-58.597 total time=   2.0s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-55.390 total time=   2.0s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-63.542 total time=   1.9s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-100.481 total time=   2.0s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-74.555 total time=   3.2s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-58.768 total time=   3.3s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-55.532 total time=   2.8s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-64.050 total time=   2.9s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-100.518 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-74.546 total time=   2.7s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-58.514 total time=   2.3s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-55.530 total time=   2.4s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-64.309 total time=   2.4s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-101.176 total time=   2.8s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-74.671 total time=   1.9s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-58.838 total time=   1.8s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-55.537 total time=   1.8s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-63.093 total time=   2.6s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-99.973 total time=   2.7s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-75.592 total time=   2.3s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-58.959 total time=   2.2s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-55.598 total time=   2.1s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-62.870 total time=   2.2s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-101.012 total time=   2.2s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-75.847 total time=   3.4s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-58.519 total time=   3.4s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-55.585 total time=   3.7s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-63.012 total time=   3.4s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-101.310 total time=   3.6s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-73.364 total time=   2.6s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-58.585 total time=   2.6s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-55.402 total time=   2.6s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-63.110 total time=   2.6s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-99.973 total time=   2.4s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-74.614 total time=   2.9s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-58.534 total time=   3.0s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-55.443 total time=   2.8s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-63.535 total time=   3.0s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-101.012 total time=   2.8s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-75.382 total time=   3.7s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-57.870 total time=   3.3s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-55.539 total time=   3.2s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-63.697 total time=   3.7s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-101.345 total time=   3.4s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-73.364 total time=   2.7s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-58.583 total time=   2.4s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-55.402 total time=   2.6s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-63.110 total time=   2.6s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-99.973 total time=   2.4s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-74.614 total time=   3.1s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-58.560 total time=   2.8s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-55.443 total time=   3.0s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-63.535 total time=   2.9s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-101.012 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-75.382 total time=   3.3s
# [CV 2/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-57.987 total time=   3.4s
# [CV 3/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-55.539 total time=   3.4s
# [CV 4/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-63.697 total time=   3.4s
# [CV 5/5] END learning_rate=0.015, max_bin=400, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-101.345 total time=   3.5s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-74.353 total time=   2.5s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-56.310 total time=   2.5s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-55.472 total time=   2.7s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-63.244 total time=   2.6s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-99.485 total time=   2.6s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-73.748 total time=   3.7s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-55.905 total time=   3.7s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-55.578 total time=   3.7s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-63.560 total time=   3.5s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-100.385 total time=   3.6s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-73.952 total time=   4.2s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-55.999 total time=   4.3s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-55.618 total time=   5.0s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-63.961 total time=   4.1s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-100.583 total time=   4.3s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-74.691 total time=   3.1s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-56.274 total time=   3.3s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-55.714 total time=   3.2s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-63.726 total time=   3.1s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-99.820 total time=   3.3s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-73.839 total time=   3.7s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-56.668 total time=   3.7s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-55.797 total time=   4.3s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-63.307 total time=   3.4s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-100.502 total time=   3.1s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-73.544 total time=   3.3s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-56.723 total time=   3.3s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-55.616 total time=   3.9s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-63.376 total time=   3.8s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-100.796 total time=   4.2s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-74.842 total time=   2.8s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-56.845 total time=   3.4s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-55.714 total time=   3.2s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-63.705 total time=   3.3s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-99.980 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-73.978 total time=   3.8s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-56.926 total time=   3.8s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-55.797 total time=   3.7s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-63.572 total time=   3.8s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-100.694 total time=   3.2s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-73.741 total time=   4.5s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-56.736 total time=   4.8s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-55.794 total time=   3.5s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-63.856 total time=   3.5s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-101.373 total time=   3.3s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-74.842 total time=   2.3s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-56.237 total time=   2.5s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-55.714 total time=   2.9s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-63.705 total time=   2.7s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-99.980 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-73.978 total time=   3.7s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-56.547 total time=   3.5s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-55.797 total time=   3.6s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-63.572 total time=   4.0s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-100.694 total time=   3.7s
# [CV 1/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-73.741 total time=   4.5s
# [CV 2/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-56.665 total time=   4.2s
# [CV 3/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-55.794 total time=   4.2s
# [CV 4/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-63.856 total time=   4.2s
# [CV 5/5] END learning_rate=0.015, max_bin=450, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-101.373 total time=   4.0s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-73.449 total time=   3.3s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-56.932 total time=   3.1s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-55.893 total time=   3.4s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-63.734 total time=   3.2s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-99.392 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-74.430 total time=   3.7s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-56.682 total time=   3.5s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-55.888 total time=   3.7s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-64.028 total time=   4.0s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-100.456 total time=   4.0s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-74.925 total time=   3.5s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-56.825 total time=   3.2s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-55.821 total time=   4.4s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-64.153 total time=   5.2s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-100.889 total time=   3.4s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-74.063 total time=   2.9s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-57.162 total time=   3.2s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-55.714 total time=   3.6s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-63.926 total time=   3.1s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-99.166 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-73.574 total time=   3.5s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-57.286 total time=   3.8s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-55.753 total time=   4.1s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-63.711 total time=   3.2s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-99.616 total time=   3.4s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-73.471 total time=   3.8s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-57.594 total time=   4.2s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-55.732 total time=   4.0s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-64.018 total time=   4.1s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-100.416 total time=   4.0s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-74.063 total time=   2.9s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-57.472 total time=   3.0s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-55.771 total time=   3.3s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-63.419 total time=   3.3s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-99.147 total time=   2.9s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-73.574 total time=   3.7s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-56.745 total time=   3.9s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-55.807 total time=   3.0s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-63.745 total time=   3.3s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-99.714 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-73.471 total time=   3.2s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-57.054 total time=   3.9s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-55.883 total time=   3.5s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-64.072 total time=   3.9s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-100.460 total time=   4.3s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-74.063 total time=   3.0s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-57.472 total time=   3.2s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-55.771 total time=   2.9s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-63.419 total time=   3.3s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-99.147 total time=   3.3s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-73.574 total time=   3.7s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-56.745 total time=   3.6s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-55.807 total time=   4.3s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-63.745 total time=   3.4s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-99.714 total time=   3.3s
# [CV 1/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-73.471 total time=   3.9s
# [CV 2/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-57.054 total time=   3.6s
# [CV 3/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-55.883 total time=   3.4s
# [CV 4/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-64.072 total time=   3.3s
# [CV 5/5] END learning_rate=0.015, max_bin=500, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-100.460 total time=   2.5s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-74.879 total time=   1.8s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-57.643 total time=   1.8s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-55.576 total time=   1.9s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-63.088 total time=   1.8s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=600, objective=mae;, score=-99.517 total time=   1.7s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-74.238 total time=   2.0s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-57.951 total time=   2.4s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-55.614 total time=   2.9s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-63.025 total time=   3.5s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=700, objective=mae;, score=-100.345 total time=   3.4s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-74.199 total time=   4.0s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-58.045 total time=   3.7s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-55.618 total time=   3.6s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-63.085 total time=   4.5s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=16, metric=mae, n_estimators=800, objective=mae;, score=-100.668 total time=   4.0s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-74.756 total time=   2.8s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-58.211 total time=   2.7s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-55.990 total time=   2.9s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-63.565 total time=   2.7s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=600, objective=mae;, score=-99.926 total time=   2.7s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-74.321 total time=   3.2s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-57.300 total time=   3.7s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-55.928 total time=   3.5s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-63.277 total time=   3.2s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=700, objective=mae;, score=-100.642 total time=   3.5s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-74.630 total time=   3.8s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-56.598 total time=   4.0s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-55.994 total time=   4.4s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-63.133 total time=   3.9s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=18, metric=mae, n_estimators=800, objective=mae;, score=-100.918 total time=   4.0s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-74.756 total time=   2.8s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-58.550 total time=   3.0s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-55.990 total time=   3.4s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-62.991 total time=   3.0s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=600, objective=mae;, score=-99.921 total time=   3.0s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-74.321 total time=   3.1s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-57.251 total time=   3.4s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-55.928 total time=   3.2s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-62.803 total time=   3.7s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=700, objective=mae;, score=-100.663 total time=   3.5s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-74.697 total time=   3.4s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-56.604 total time=   2.9s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-55.994 total time=   3.0s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-63.273 total time=   3.5s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=20, metric=mae, n_estimators=800, objective=mae;, score=-100.997 total time=   2.9s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-74.756 total time=   2.5s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-58.550 total time=   2.2s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-55.990 total time=   2.7s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-62.991 total time=   2.8s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=600, objective=mae;, score=-99.921 total time=   5.1s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-74.321 total time=   3.9s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-57.251 total time=   4.0s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-55.928 total time=   4.0s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-62.803 total time=   3.5s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=700, objective=mae;, score=-100.663 total time=   3.5s
# [CV 1/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-74.697 total time=   4.0s
# [CV 2/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-56.604 total time=   3.9s
# [CV 3/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-55.994 total time=   3.4s
# [CV 4/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-63.350 total time=   3.2s
# [CV 5/5] END learning_rate=0.015, max_bin=550, max_depth=22, metric=mae, n_estimators=800, objective=mae;, score=-100.997 total time=   4.1s
# LGBMRegressor 5 CV 시 최적 평균 MAE 값 69.7727
# 최적 alpha:{'learning_rate': 0.015, 'max_bin': 450, 'max_depth': 16, 'metric': 'mae', 'n_estimators': 600, 'objective': 'mae'}

# %%
lgb_preds_dinner = lgb_estimator_dinner.predict(test_dinner_features, axis=1)

# %%
submission["석식계"] = lgb_preds_dinner
submission
# Out:
#             일자          중식계         석식계
# 0   2021-01-27   898.136383  381.142783
# 1   2021-01-28   808.815487  486.492837
# 2   2021-01-29   676.974474  271.055405
# 3   2021-02-01  1169.708221  534.352722
# 4   2021-02-02   917.988752  516.391492
# 5   2021-02-03   895.065053  403.425459
# 6   2021-02-04   842.421838  491.011821
# 7   2021-02-05   693.867226  342.451046
# 8   2021-02-08  1167.547081  520.862264
# 9   2021-02-09   928.236652  540.024111
# 10  2021-02-10   773.409673  335.175852
# 11  2021-02-15  1132.679646  515.244983
# 12  2021-02-16   931.178570  520.675198
# 13  2021-02-17   859.616830  434.988714
# 14  2021-02-18   894.953799  490.015927
# 15  2021-02-19   705.148466  388.372566
# 16  2021-02-22  1152.861912  543.953184
# 17  2021-02-23   843.205427  500.386752
# 18  2021-02-24   894.037088  387.470177
# 19  2021-02-25   848.370263  501.373980
# 20  2021-02-26   667.791949  404.557383
# 21  2021-03-02   901.542493  510.425030
# 22  2021-03-03   872.033663  416.394071
# 23  2021-03-04   796.352024  502.209352
# 24  2021-03-05   630.708995  401.676106
# 25  2021-03-08  1131.425022  552.155314
# 26  2021-03-09   928.304861  545.564008
# 27  2021-03-10   872.877283  419.298690
# 28  2021-03-11   803.544595  496.247731
# 29  2021-03-12   670.827797  355.694155
# 30  2021-03-15  1178.025992  547.666065
# 31  2021-03-16   952.593014  524.138155
# 32  2021-03-17   914.672494  454.136451
# 33  2021-03-18   882.538426  495.231950
# 34  2021-03-19   653.320844  349.692887
# 35  2021-03-22  1186.518200  537.062524
# 36  2021-03-23   942.648140  542.961964
# 37  2021-03-24   913.238322  437.701054
# 38  2021-03-25   819.578510  489.572895
# 39  2021-03-26   697.994769  366.170305
# 40  2021-03-29  1191.659350  529.607641
# 41  2021-03-30   890.640598  512.123214
# 42  2021-03-31   914.396245  483.710975
# 43  2021-04-01   810.586768  498.176395
# 44  2021-04-02   682.787221  381.882003
# 45  2021-04-05  1199.852030  551.699232
# 46  2021-04-06   923.755248  542.974456
# 47  2021-04-07   897.236097  426.326025
# 48  2021-04-08   851.110187  498.695675
# 49  2021-04-09   668.192103  374.027369

# %%
submission.to_csv('submission_성동현.csv', index = False, encoding = "UTF-8")
